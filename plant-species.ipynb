# %% [markdown]
# # Plant Species

# %% [markdown]
# Classify citrus trees

# %%
from fastai.vision import *

# %%
path = Path('data/citrus')

# %%
dest = path/'lime'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'lemon'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'orange'
dest.mkdir(parents=True, exist_ok=True)

dest = path/'grapefruit'
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/citrus/lemon'),
#  PosixPath('data/citrus/lime'),
#  PosixPath('data/citrus/orange'),
#  PosixPath('data/citrus/grapefruit')]

# %% [markdown]
# ### Once txt files are uploaded, download the actual images:

# %%
download_images(path/"lime/lime.txt", path/"lime", max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:15<00:00]
#     </div>
# Error https://monroviacdn.azureedge.net/plants/7649.jpg HTTPSConnectionPool(host='monroviacdn.azureedge.net', port=443): Read timed out. (read timeout=4)
# ...

# %%
download_images(path/"lemon/lemon.txt", path/"lemon", max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# ...

# %%
download_images(path/"orange/orange.txt", path/"orange", max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:17<00:00]
#     </div>
# ...

# %%
download_images(path/"grapefruit/grapefruit.txt", path/"grapefruit", max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:11<00:00]
#     </div>
# Error https://cgaxisimg.ams3.cdn.digitaloceanspaces.com/2018/07/cgaxis_models_105_28-00.jpg HTTPSConnectionPool(host='cgaxisimg.ams3.cdn.digitaloceanspaces.com', port=443): Read timed out. (read timeout=4)
# ...

# %%
classes = ['lime','lemon','orange','grapefruit']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# lime
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='195' class='' max='195', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [195/195 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/citrus/lime/00000139.png'>
# cannot identify image file <_io.BufferedReader name='data/citrus/lime/00000149.jpg'>
# cannot identify image file <_io.BufferedReader name='data/citrus/lime/00000072.jpg'>
# ...

# %% [markdown]
# ## View Data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['grapefruit', 'lemon', 'lime', 'orange']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['grapefruit', 'lemon', 'lime', 'orange'], 4, 596, 149)

# %% [markdown]
# ## Training the model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:23 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.675388</td>
#       <td>1.180052</td>
#       <td>0.557047</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.379165</td>
#       <td>0.857294</td>
#       <td>0.355705</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.169499</td>
#       <td>0.799905</td>
#       <td>0.335570</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.037608</td>
#       <td>0.790786</td>
#       <td>0.342282</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.780378</td>
#       <td>0.754092</td>
#       <td>0.322148</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.670029</td>
#       <td>0.728307</td>
#       <td>0.328859</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning up

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:03<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# ### ...hmmm 🤔it seems we can't display wdigets

# %% [markdown]
# well... that's a good error rate for now

# %% [markdown]
# ## Trying it out

# %%
learn.export()

# %% [markdown]
# Notice that a file called 'export.pkl' has been created inside `path`

# %%
learn_prod = load_learner(path)

# %%
img = open_image(path/'lemon'/'00000029.jpg')
img
# Out:
# Image (3, 500, 500)

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img)
pred_class
# Out:
# Category lemon

# %%
img = open_image(path/'lime'/'00000029.jpg')
img
# Out:
# Image (3, 500, 418)

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img)
pred_class
# Out:
# Category lemon

# %% [markdown]
# ### Shit, here it failed!

# %%
img = open_image(path/'lime'/'00000011.jpg')
img
# Out:
# Image (3, 500, 400)

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img)
pred_class
# Out:
# Category lime

# %% [markdown]
# ### Here it didn't, probs was way too obvious!

# %%
img = open_image(path/'grapefruit'/'00000011.jpg')
img
# Out:
# Image (3, 500, 500)

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img)
pred_class
# Out:
# Category grapefruit

# %%
img1 = open_image(path/'grapefruit'/'00000001.jpg')
img2 = open_image(path/'grapefruit'/'00000002.jpg')
img3 = open_image(path/'grapefruit'/'00000003.jpg')

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img1)
pred_class
# Out:
# Category grapefruit

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img2)
pred_class
# Out:
# Category grapefruit

# %%
pred_class,pred_idx,outputs = learn_prod.predict(img3)
pred_class
# Out:
# Category grapefruit

# %% [markdown]
# ### Hmmm not bad
